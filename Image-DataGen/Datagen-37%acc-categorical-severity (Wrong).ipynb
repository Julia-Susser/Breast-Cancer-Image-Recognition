# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("data.csv")

# %%
corrmat = df.corr()
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))
ax.set_title("Correlation Matrix", fontsize=12)
filter = df.columns != 'id'
sns.heatmap(df[df.columns[filter]].corr(), vmin=-1, vmax=1, cmap='coolwarm', annot=True)

# %%
import os
images = ["all-mias/"+x for x in os.listdir("all-mias")]
images
# Out:
# ['all-mias/mdb149.pgm',
#  'all-mias/mdb161.pgm',
#  'all-mias/mdb175.pgm',
#  'all-mias/mdb029.pgm',
#  'all-mias/mdb015.pgm',
#  'all-mias/mdb001.pgm',
#  'all-mias/mdb217.pgm',
#  'all-mias/mdb203.pgm',
#  'all-mias/mdb202.pgm',
#  'all-mias/mdb216.pgm',
#  'all-mias/mdb014.pgm',
#  'all-mias/mdb028.pgm',
#  'all-mias/mdb174.pgm',
#  'all-mias/mdb160.pgm',
#  'all-mias/mdb148.pgm',
#  'all-mias/mdb189.pgm',
#  'all-mias/mdb176.pgm',
#  'all-mias/mdb162.pgm',
#  'all-mias/mdb002.pgm',
#  'all-mias/mdb016.pgm',
#  'all-mias/mdb228.pgm',
#  'all-mias/mdb200.pgm',
#  'all-mias/mdb214.pgm',
#  'all-mias/mdb215.pgm',
#  'all-mias/mdb201.pgm',
#  'all-mias/mdb229.pgm',
#  'all-mias/mdb017.pgm',
#  'all-mias/mdb003.pgm',
#  'all-mias/mdb163.pgm',
#  'all-mias/mdb177.pgm',
#  'all-mias/mdb188.pgm',
#  'all-mias/mdb198.pgm',
#  'all-mias/mdb173.pgm',
#  'all-mias/mdb167.pgm',
#  'all-mias/mdb007.pgm',
#  'all-mias/mdb013.pgm',
#  'all-mias/mdb205.pgm',
#  'all-mias/mdb211.pgm',
#  'all-mias/mdb239.pgm',
#  'all-mias/mdb238.pgm',
#  'all-mias/mdb210.pgm',
#  'all-mias/mdb204.pgm',
#  'all-mias/mdb012.pgm',
#  'all-mias/mdb006.pgm',
#  'all-mias/mdb166.pgm',
#  'all-mias/mdb172.pgm',
#  'all-mias/mdb199.pgm',
#  'all-mias/mdb164.pgm',
#  'all-mias/mdb170.pgm',
#  'all-mias/mdb158.pgm',
#  'all-mias/mdb010.pgm',
#  'all-mias/mdb004.pgm',
#  'all-mias/mdb038.pgm',
#  'all-mias/mdb212.pgm',
#  'all-mias/mdb206.pgm',
#  'all-mias/mdb207.pgm',
#  'all-mias/mdb213.pgm',
#  'all-mias/mdb039.pgm',
#  'all-mias/mdb005.pgm',
#  'all-mias/mdb011.pgm',
#  'all-mias/mdb159.pgm',
#  'all-mias/mdb171.pgm',
#  'all-mias/mdb165.pgm',
#  'all-mias/mdb300.pgm',
#  'all-mias/mdb314.pgm',
#  'all-mias/mdb102.pgm',
#  'all-mias/mdb116.pgm',
#  'all-mias/mdb089.pgm',
#  'all-mias/mdb076.pgm',
#  'all-mias/mdb062.pgm',
#  'all-mias/mdb248.pgm',
#  'all-mias/mdb274.pgm',
#  'all-mias/mdb260.pgm',
#  'all-mias/mdb261.pgm',
#  'all-mias/mdb275.pgm',
#  'all-mias/mdb249.pgm',
#  'all-mias/Info.txt',
#  'all-mias/mdb063.pgm',
#  'all-mias/mdb077.pgm',
#  'all-mias/mdb088.pgm',
#  'all-mias/mdb117.pgm',
#  'all-mias/mdb103.pgm',
#  'all-mias/mdb315.pgm',
#  'all-mias/mdb301.pgm',
#  'all-mias/mdb317.pgm',
#  'all-mias/mdb303.pgm',
#  'all-mias/mdb129.pgm',
#  'all-mias/mdb115.pgm',
#  'all-mias/mdb101.pgm',
#  'all-mias/mdb049.pgm',
#  'all-mias/mdb061.pgm',
#  'all-mias/mdb075.pgm',
#  'all-mias/mdb288.pgm',
#  'all-mias/mdb263.pgm',
#  'all-mias/mdb277.pgm',
#  'all-mias/mdb276.pgm',
#  'all-mias/mdb262.pgm',
#  'all-mias/mdb289.pgm',
#  'all-mias/mdb074.pgm',
#  'all-mias/mdb060.pgm',
#  'all-mias/mdb048.pgm',
#  'all-mias/mdb100.pgm',
#  'all-mias/mdb114.pgm',
#  'all-mias/mdb128.pgm',
#  'all-mias/mdb302.pgm',
#  'all-mias/mdb316.pgm',
#  'all-mias/mdb312.pgm',
#  'all-mias/mdb306.pgm',
#  'all-mias/mdb110.pgm',
#  'all-mias/mdb104.pgm',
#  'all-mias/mdb138.pgm',
#  'all-mias/mdb064.pgm',
#  'all-mias/mdb070.pgm',
#  'all-mias/mdb058.pgm',
#  'all-mias/mdb299.pgm',
#  'all-mias/mdb266.pgm',
#  'all-mias/mdb272.pgm',
#  'all-mias/mdb273.pgm',
#  'all-mias/mdb267.pgm',
#  'all-mias/mdb298.pgm',
#  'all-mias/mdb059.pgm',
#  'all-mias/mdb071.pgm',
#  'all-mias/mdb065.pgm',
#  'all-mias/mdb139.pgm',
#  'all-mias/mdb105.pgm',
#  'all-mias/mdb111.pgm',
#  'all-mias/mdb307.pgm',
#  'all-mias/mdb313.pgm',
#  'all-mias/mdb305.pgm',
#  'all-mias/mdb311.pgm',
#  'all-mias/mdb107.pgm',
#  'all-mias/mdb113.pgm',
#  'all-mias/mdb098.pgm',
#  'all-mias/mdb073.pgm',
#  'all-mias/mdb067.pgm',
#  'all-mias/mdb271.pgm',
#  'all-mias/mdb265.pgm',
#  'all-mias/mdb259.pgm',
#  'all-mias/mdb258.pgm',
#  'all-mias/mdb264.pgm',
#  'all-mias/mdb270.pgm',
#  'all-mias/Licence.txt',
#  'all-mias/mdb066.pgm',
#  'all-mias/mdb072.pgm',
#  'all-mias/mdb099.pgm',
#  'all-mias/mdb112.pgm',
#  'all-mias/mdb106.pgm',
#  'all-mias/README',
#  'all-mias/mdb310.pgm',
#  'all-mias/mdb304.pgm',
#  'all-mias/mdb309.pgm',
#  'all-mias/mdb321.pgm',
#  'all-mias/mdb123.pgm',
#  'all-mias/mdb137.pgm',
#  'all-mias/mdb094.pgm',
#  'all-mias/mdb080.pgm',
#  'all-mias/mdb057.pgm',
#  'all-mias/mdb043.pgm',
#  'all-mias/mdb296.pgm',
#  'all-mias/mdb282.pgm',
#  'all-mias/mdb269.pgm',
#  'all-mias/mdb255.pgm',
#  'all-mias/mdb241.pgm',
#  'all-mias/mdb240.pgm',
#  'all-mias/mdb254.pgm',
#  'all-mias/mdb268.pgm',
#  'all-mias/mdb283.pgm',
#  'all-mias/mdb297.pgm',
#  'all-mias/mdb042.pgm',
#  'all-mias/mdb056.pgm',
#  'all-mias/mdb081.pgm',
#  'all-mias/mdb095.pgm',
#  'all-mias/mdb136.pgm',
#  'all-mias/mdb122.pgm',
#  'all-mias/mdb320.pgm',
#  'all-mias/mdb308.pgm',
#  'all-mias/mdb322.pgm',
#  'all-mias/mdb108.pgm',
#  'all-mias/mdb134.pgm',
#  'all-mias/mdb120.pgm',
#  'all-mias/mdb083.pgm',
#  'all-mias/mdb097.pgm',
#  'all-mias/mdb068.pgm',
#  'all-mias/mdb040.pgm',
#  'all-mias/mdb054.pgm',
#  'all-mias/mdb281.pgm',
#  'all-mias/mdb295.pgm',
#  'all-mias/mdb242.pgm',
#  'all-mias/mdb256.pgm',
#  'all-mias/mdb257.pgm',
#  'all-mias/mdb243.pgm',
#  'all-mias/mdb294.pgm',
#  'all-mias/mdb280.pgm',
#  'all-mias/mdb055.pgm',
#  'all-mias/mdb041.pgm',
#  'all-mias/mdb069.pgm',
#  'all-mias/mdb096.pgm',
#  'all-mias/mdb082.pgm',
#  'all-mias/mdb121.pgm',
#  'all-mias/mdb135.pgm',
#  'all-mias/mdb109.pgm',
#  'all-mias/mdb131.pgm',
#  'all-mias/mdb125.pgm',
#  'all-mias/mdb119.pgm',
#  'all-mias/mdb086.pgm',
#  'all-mias/mdb092.pgm',
#  'all-mias/mdb045.pgm',
#  'all-mias/mdb051.pgm',
#  'all-mias/mdb079.pgm',
#  'all-mias/mdb284.pgm',
#  'all-mias/mdb290.pgm',
#  'all-mias/mdb247.pgm',
#  'all-mias/mdb253.pgm',
#  'all-mias/mdb252.pgm',
#  'all-mias/mdb246.pgm',
#  'all-mias/mdb291.pgm',
#  'all-mias/mdb285.pgm',
#  'all-mias/mdb078.pgm',
#  'all-mias/mdb050.pgm',
#  'all-mias/mdb044.pgm',
#  'all-mias/mdb093.pgm',
#  'all-mias/mdb087.pgm',
#  'all-mias/mdb118.pgm',
#  'all-mias/mdb124.pgm',
#  'all-mias/mdb130.pgm',
#  'all-mias/mdb318.pgm',
#  'all-mias/mdb126.pgm',
#  'all-mias/mdb132.pgm',
#  'all-mias/mdb091.pgm',
#  'all-mias/mdb085.pgm',
#  'all-mias/mdb052.pgm',
#  'all-mias/mdb046.pgm',
#  'all-mias/mdb293.pgm',
#  'all-mias/mdb287.pgm',
#  'all-mias/mdb250.pgm',
#  'all-mias/mdb244.pgm',
#  'all-mias/mdb278.pgm',
#  'all-mias/mdb279.pgm',
#  'all-mias/mdb245.pgm',
#  'all-mias/mdb251.pgm',
#  'all-mias/mdb286.pgm',
#  'all-mias/mdb292.pgm',
#  'all-mias/mdb047.pgm',
#  'all-mias/mdb053.pgm',
#  'all-mias/mdb084.pgm',
#  'all-mias/mdb090.pgm',
#  'all-mias/mdb133.pgm',
#  'all-mias/mdb127.pgm',
#  'all-mias/mdb319.pgm',
#  'all-mias/mdb183.pgm',
#  'all-mias/mdb197.pgm',
#  'all-mias/mdb168.pgm',
#  'all-mias/mdb140.pgm',
#  'all-mias/mdb154.pgm',
#  'all-mias/mdb008.pgm',
#  'all-mias/mdb034.pgm',
#  'all-mias/mdb020.pgm',
#  'all-mias/mdb236.pgm',
#  'all-mias/mdb222.pgm',
#  'all-mias/mdb223.pgm',
#  'all-mias/mdb237.pgm',
#  'all-mias/mdb021.pgm',
#  'all-mias/mdb035.pgm',
#  'all-mias/mdb009.pgm',
#  'all-mias/mdb155.pgm',
#  'all-mias/mdb141.pgm',
#  'all-mias/mdb169.pgm',
#  'all-mias/mdb196.pgm',
#  'all-mias/mdb182.pgm',
#  'all-mias/mdb194.pgm',
#  'all-mias/mdb180.pgm',
#  'all-mias/mdb157.pgm',
#  'all-mias/mdb143.pgm',
#  'all-mias/mdb023.pgm',
#  'all-mias/mdb037.pgm',
#  'all-mias/mdb209.pgm',
#  'all-mias/mdb221.pgm',
#  'all-mias/mdb235.pgm',
#  'all-mias/mdb234.pgm',
#  'all-mias/mdb220.pgm',
#  'all-mias/mdb208.pgm',
#  'all-mias/mdb036.pgm',
#  'all-mias/mdb022.pgm',
#  'all-mias/mdb142.pgm',
#  'all-mias/mdb156.pgm',
#  'all-mias/mdb181.pgm',
#  'all-mias/mdb195.pgm',
#  'all-mias/mdb191.pgm',
#  'all-mias/mdb185.pgm',
#  'all-mias/mdb152.pgm',
#  'all-mias/mdb146.pgm',
#  'all-mias/mdb026.pgm',
#  'all-mias/mdb032.pgm',
#  'all-mias/mdb224.pgm',
#  'all-mias/mdb230.pgm',
#  'all-mias/mdb218.pgm',
#  'all-mias/mdb219.pgm',
#  'all-mias/mdb231.pgm',
#  'all-mias/mdb225.pgm',
#  'all-mias/mdb033.pgm',
#  'all-mias/mdb027.pgm',
#  'all-mias/mdb147.pgm',
#  'all-mias/mdb153.pgm',
#  'all-mias/mdb184.pgm',
#  'all-mias/mdb190.pgm',
#  'all-mias/mdb186.pgm',
#  'all-mias/mdb192.pgm',
#  'all-mias/mdb145.pgm',
#  'all-mias/mdb151.pgm',
#  'all-mias/mdb179.pgm',
#  'all-mias/mdb031.pgm',
#  'all-mias/mdb025.pgm',
#  'all-mias/mdb019.pgm',
#  'all-mias/mdb233.pgm',
#  'all-mias/mdb227.pgm',
#  'all-mias/mdb226.pgm',
#  'all-mias/mdb232.pgm',
#  'all-mias/mdb018.pgm',
#  'all-mias/mdb024.pgm',
#  'all-mias/mdb030.pgm',
#  'all-mias/mdb178.pgm',
#  'all-mias/mdb150.pgm',
#  'all-mias/mdb144.pgm',
#  'all-mias/mdb193.pgm',
#  'all-mias/mdb187.pgm']

# %%
import matplotlib.image as mpimg
img = mpimg.imread(df.filename[0])
plt.imshow(img)

# %%
from PIL import Image
for x in df.REFNUM:
    Image.open("all-mias/%s.pgm"%x).save("files/%s.png"%x)

# %%
df = pd.read_csv("info.txt", delimiter=" ")
df["filename"] = "files/" + df.REFNUM +".png"
df.CLASS.unique()
# Out:
# array(['CIRC', 'NORM', 'MISC', 'ASYM', 'ARCH', 'SPIC', 'CALC'],
#       dtype=object)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
df["SEVERITY"] = df["SEVERITY"].fillna("None")
train_df = df.loc[:len(df)*.6-1]
validation_df = df.loc[len(df)*.6:]
# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)

# Flow training images in batches of 128 using train_datagen generator
train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        x_col = 'filename',
        y_col = 'SEVERITY',
        target_size=(300, 300),  # All images will be resized to 300x300
        batch_size=32,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='categorical')

validation_generator = validation_datagen.flow_from_dataframe(
        dataframe=validation_df,
        x_col = 'filename',
        y_col = 'SEVERITY',
        target_size=(300, 300),  # All images will be resized to 300x300
        batch_size=32,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='categorical')
# Out:
# Found 198 validated image filenames belonging to 3 classes.
# Found 132 validated image filenames belonging to 3 classes.

# %%
import tensorflow as tf
num_classes = 3
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (5,5), input_shape = (300 , 300 , 3), activation = 'relu'),
    tf.keras.layers.MaxPool2D(3,3),
    tf.keras.layers.Conv2D(64, (5,5) , activation = 'relu'),
    tf.keras.layers.MaxPool2D((3,3)),
    tf.keras.layers.Conv2D(128 , (5,5) , activation = 'relu'),
    tf.keras.layers.MaxPool2D(3,3),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5, seed = 5),
    tf.keras.layers.Dense(128 , activation = 'relu'),
    tf.keras.layers.Dense(num_classes , activation = 'softmax')])

# %%
model.compile(loss = 'categorical_crossentropy' , optimizer = tf.keras.optimizers.Adam(lr = 0.001) , metrics = 'accuracy')

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 296, 296, 32)      2432
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 98, 98, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 94, 94, 64)        51264
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 27, 27, 128)       204928
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 9, 9, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 10368)             0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 10368)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               1327232
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 1,586,243
# Trainable params: 1,586,243
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.85):
      print("\nReached 60% accuracy so cancelling training!")
      self.model.stop_training = True


callbacks = myCallback()

# %%
history = model.fit(train_generator ,
          validation_data = validation_generator ,
          epochs = 15 ,
          steps_per_epoch = len(train_df)/32, # train_files/batch_size
          validation_steps = len(validation_df)/32, # valid_files/batch_size 
          callbacks = [callbacks])
# Out:
# Epoch 1/15
# 6/6 [==============================] - 18s 3s/step - loss: 1.1957 - accuracy: 0.5039 - val_loss: 1.0146 - val_accuracy: 0.6439
# Epoch 2/15
# 6/6 [==============================] - 20s 3s/step - loss: 0.9643 - accuracy: 0.6225 - val_loss: 0.9883 - val_accuracy: 0.6439
# Epoch 3/15
# 6/6 [==============================] - 20s 4s/step - loss: 0.9089 - accuracy: 0.6519 - val_loss: 0.9901 - val_accuracy: 0.6439
# Epoch 4/15
# 6/6 [==============================] - 18s 3s/step - loss: 0.8741 - accuracy: 0.6426 - val_loss: 1.0052 - val_accuracy: 0.6439
# Epoch 5/15
# 6/6 [==============================] - 20s 3s/step - loss: 0.8534 - accuracy: 0.6425 - val_loss: 1.0796 - val_accuracy: 0.5000
# Epoch 6/15
# 6/6 [==============================] - 20s 3s/step - loss: 0.8330 - accuracy: 0.6251 - val_loss: 1.0986 - val_accuracy: 0.4924
# Epoch 7/15
# 6/6 [==============================] - 20s 3s/step - loss: 0.8143 - accuracy: 0.6717 - val_loss: 1.0424 - val_accuracy: 0.5985
# Epoch 8/15
# 6/6 [==============================] - 19s 3s/step - loss: 0.7842 - accuracy: 0.6655 - val_loss: 1.0697 - val_accuracy: 0.5379
# Epoch 9/15
# 6/6 [==============================] - 20s 3s/step - loss: 0.7612 - accuracy: 0.6294 - val_loss: 1.1889 - val_accuracy: 0.5606
# Epoch 10/15
# 6/6 [==============================] - 21s 4s/step - loss: 0.7755 - accuracy: 0.6506 - val_loss: 1.1014 - val_accuracy: 0.5303
# Epoch 11/15
# 6/6 [==============================] - 26s 4s/step - loss: 0.6486 - accuracy: 0.7146 - val_loss: 1.1112 - val_accuracy: 0.4924
# Epoch 12/15
# 6/6 [==============================] - 19s 3s/step - loss: 0.6848 - accuracy: 0.6754 - val_loss: 1.2633 - val_accuracy: 0.5076
# Epoch 13/15
# 6/6 [==============================] - 19s 3s/step - loss: 0.6162 - accuracy: 0.7336 - val_loss: 1.1948 - val_accuracy: 0.5000
# Epoch 14/15
# 6/6 [==============================] - 19s 3s/step - loss: 0.6188 - accuracy: 0.6928 - val_loss: 1.4065 - val_accuracy: 0.4848
# Epoch 15/15
# 6/6 [==============================] - 19s 4s/step - loss: 0.5098 - accuracy: 0.8276 - val_loss: 1.6304 - val_accuracy: 0.3712

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
labels = (train_generator.class_indices)
labels = dict((v , k) for k , v in labels.items())
print(labels)
def prediction(test_path):
    img = image.load_img(test_path , target_size = (300 , 300))
    img = image.img_to_array(img, dtype=np.uint8)
    img = np.array(img)/300.0
        
    plt.title('Image')
    plt.axis('off')
    plt.imshow(img.squeeze())
        
    predict = model.predict(img[np.newaxis , ...])
    predicted_class = labels[np.argmax(predict[0] , axis = -1)]
        
    print('Prediction Value: ' , np.max(predict[0] , axis = -1))
    print("Classified:",predicted_class)
# Out:
# {0: 'B', 1: 'M', 2: 'None'}

# %%
prediction(validation_df.iloc[1].filename)
# Out:
# Prediction Value:  0.6690539
# Classified: M

# %%
validation_df.iloc[1]
# Out:
# REFNUM                  mdb197
# BG                           D
# CLASS                     NORM
# SEVERITY                  None
# X                          NaN
# Y                          NaN
# RADIUS                     NaN
# Unnamed: 7                 NaN
# filename      files/mdb197.png
# Name: 199, dtype: object
